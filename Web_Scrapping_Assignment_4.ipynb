# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchAttributeException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import UnexpectedTagNameException
import time

# %% [markdown]
# # Q1. Scrape the details of most viewed videos on YouTube from Wikipedia:
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
#
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
rank=[]
name=[]
artist=[]
date=[]
views=[]
for k in range(1,31):
    try:
        for i in driver.find_elements_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr[{}]/td[1]".format(k)):
            rank.append(i.text)
    except NoSuchAttributeException as e:
        rank.append('--')
        
    
    try:
        for i in driver.find_elements_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr[{}]/td[2]".format(k)):
            name.append(i.text)
    except NoSuchAttributeException as e:
        name.append('--')
        
        
    try:
        for i in driver.find_elements_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr[{}]/td[3]".format(k)):
            artist.append(i.text)
    except NoSuchAttributeException as e:
        artist.append('--')
    try:
        for i in driver.find_elements_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr[{}]/td[4]".format(k)):
            views.append(i.text)
    except NoSuchAttributeException as e:
        views.append('--')
    try:
        for i in driver.find_elements_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr[{}]/td[5]".format(k)):
            date.append(i.text)
    except NoSuchAttributeException as e:
        date.append('--')

# %%
print(len(rank))
print(len(name))
print(len(artist))
print(len(date))
print(len(views))
# Out:
# 30
# 30
# 30
# 30
# 30

# %%
df=pd.DataFrame({'Rank':rank,'Name':name,'Artist':artist,'Upload date':date,'Views':views})

# %%
df
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                       "Johny Johny Yes Papa"[25]
# 3    4.                               "Shape of You"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                  "Bath Song"[31]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 8    9.                                "Uptown Funk"[33]
# 9   10.                              "Gangnam Style"[34]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                             "Dame Tu Cosita"[38]
# 13  14.                                      "Sorry"[39]
# 14  15.                                       "Roar"[40]
# ...

# %% [markdown]
# # Q2. Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/. You need to find following details:
#
# A) Match title (I.e. 1st ODI) B) Series C) Place D) Date E) Time Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
url='https://www.bcci.tv/'
driver.get(url)

# %%
bcci=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']")
bcci.click()

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]
a=[]
for i in driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[2]"):
    Series.append(i.text)
for i in driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/strong"):
    Match_title.append(i.text)
for i in driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span"):
    Place.append(i.text)
for i in driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[2]"):
    Time.append(i.text)
# for date
c=[]
for i in driver.find_elements_by_xpath("//div[@class='js-list']/h3"):
    c.append(i.text)
k=[]
for i in driver.find_elements_by_xpath("//div[@class='fixture__full-date']/span"):
    k.append(i.text)
for i in c:
    if i=='July 2021':
        Date.append(k[0]+' '+c[0])
        Date.append(k[1]+" "+c[0])
        Date.append(k[2]+" "+c[0])
        Date.append(k[3]+' '+c[0])
        Date.append(k[4]+' '+c[0])
        Date.append(k[5]+' '+c[0])
        
    if i=='August 2021':
        Date.append(k[6]+" "+c[1])
        Date.append(k[7]+" "+c[1])
        Date.append(k[8]+' '+c[1])
    if i=='September 2021':
         Date.append(k[9]+" "+c[2])
         Date.append(k[10]+" "+c[2])

# %%
print(len(Match_title))
print(len(Series))
print(len(Place))
print(len(Date))
print(len(Time))
# Out:
# 11
# 11
# 11
# 11
# 11

# %%
df = pd.DataFrame({"Series" : Series,
                   "Match Title" : Match_title,
                            "Place" : Place,
                            "Date" : Date,
                            "Time" : Time})

# %%
df
# Out:
#                     Series Match Title                         Place  \
# 0   SRI LANKA V INDIA 2021     1st ODI  R Premadasa Stadium, Colombo
# 1   SRI LANKA V INDIA 2021     2nd ODI  R Premadasa Stadium, Colombo
# 2   SRI LANKA V INDIA 2021     3rd ODI  R Premadasa Stadium, Colombo
# 3   SRI LANKA V INDIA 2021    1st T20I  R Premadasa Stadium, Colombo
# 4   SRI LANKA V INDIA 2021    2nd T20I  R Premadasa Stadium, Colombo
# 5   SRI LANKA V INDIA 2021    3rd T20I  R Premadasa Stadium, Colombo
# 6     ENGLAND V INDIA 2021    1st Test      Trent Bridge, Nottingham
# 7     ENGLAND V INDIA 2021    2nd Test                Lord's, London
# 8     ENGLAND V INDIA 2021    3rd Test             Headingley, Leeds
# 9     ENGLAND V INDIA 2021    4th Test              The Oval, London
# 10    ENGLAND V INDIA 2021    5th Test      Old Trafford, Manchester
#
#                  Date       Time
# 0        18 July 2021  15:00 IST
# 1        20 July 2021  15:00 IST
# 2        23 July 2021  15:00 IST
# ...

# %% [markdown]
# # Q3. Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/ You need to find following details:
#
# A) Name B) Description Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
url='https://www.guru99.com/'
driver.get(url)

# %%
g=driver.find_element_by_xpath("//a[@title='Selenium']")
g.click()

# %%
try:
    exc_han=driver.find_element_by_xpath("//a[@title = 'Selenium Exception Handling (Common Exceptions List)']")
    exc_han.click()
except NoSuchAttributeException as e:
    driver.get(exc_han.get_attribute('href'))

# %%
exception_name=[]
description=[]
for j in range(2,43):
    for i in driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr[{}]/td[2]".format(j)):
        description.append(i.text)
    for i in driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr[{}]/td[1]".format(j)):
        exception_name.append(i.text)

# %%
print(len(exception_name))
print(len(description))
# Out:
# 41
# 41

# %%
df=pd.DataFrame({'Name':exception_name,'Description':description})

# %%
df
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# # Q4. Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)

# %%
url='http://statisticstimes.com/'
driver.get(url)

# %%
stat=driver.find_element_by_xpath("//div[@class='dropdown-content']/a[3]")
driver.get(stat.get_attribute('href'))

# %%
Rank=[]
State=[]
GSDP_19_20=[]
GSDP_18_19=[]
Share=[]
GDP=[]
for i in driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[1]"):
    Rank.append(i.text)
for i in driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[2]"):
    State.append(i.text)   
for i in driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[3]"):
    GSDP_19_20.append(i.text)  
for i in driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[8]"):
    GSDP_18_19.append(i.text)
for i in driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[5]"):
    Share.append(i.text)   
for i in driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[6]"):
    GDP.append(i.text)

# %%
print(len(Rank))
print(len(State))
print(len(GSDP_19_20))
print(len(GSDP_18_19))
print(len(Share))
print(len(GDP))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33

# %%
df=pd.DataFrame({'Rank':Rank,'State':State,'GSDP 19-20':GSDP_19_20,'GSDP 18-19':GSDP_18_19,'Share':Share,'GDP($Billion)':GDP})

# %%
df
# Out:
#    Rank                      State GSDP 19-20 GSDP 18-19   Share GDP($Billion)
# 0     1                Maharashtra          -  2,039,074  13.94%       399.921
# 1     2                 Tamil Nadu  1,845,853  1,215,307   8.63%       247.629
# 2     3              Uttar Pradesh  1,687,818  1,123,982   8.39%       240.726
# 3     4                    Gujarat          -  1,186,379   7.96%       228.290
# 4     5                  Karnataka  1,631,977  1,091,077   7.91%       226.806
# 5     6                West Bengal  1,253,832    739,525   5.77%       165.556
# 6     7                  Rajasthan  1,020,989    677,428   4.99%       143.179
# 7     8             Andhra Pradesh    972,782    621,301   4.57%       131.083
# 8     9                  Telangana    969,604    612,828   4.56%       130.791
# 9    10             Madhya Pradesh    906,672    522,009   4.29%       122.977
# 10   11                     Kerala          -    559,412   4.14%       118.733
# ...

# %% [markdown]
# # Q5. Scrape the details of trending repositories on Github.com.¶
#
# Url = https://github.com/ You have to find the following details:
#
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
url='https://github.com/'
driver.get(url)

# %%
trend=driver.find_element_by_xpath("//ul[@class='list-style-none mb-3']/li[3]/a")
driver.get(trend.get_attribute('href'))

# %%
urls=[]
url_element=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
for i in url_element:
    urls.append(i.get_attribute("href"))

# %%
R_title=[]
R_description=[]
contribution=[]
language=[]
try:
    for i in driver.find_elements_by_xpath("//a[@class='Link--muted d-inline-block mr-3']"):
        contribution.append(i.text)
except:
    contribution.append('-')
for l in urls:
    driver.get(l)
    time.sleep(2)
    try:
        for i in driver.find_elements_by_xpath("//p[@class='f4 mt-3']"):
            des.append(i.text)
    except:
        R_description.append('-')
    try:
        for i in driver.find_elements_by_xpath("//strong[@class='mr-2 flex-self-stretch']"):
            R_title.append(i.text)
    except:
        title.append('-')
   
    try:
        for i in driver.find_elements_by_xpath("//span[@class='color-text-primary text-bold mr-1']"):
            language.append(i.text)
    except:
        language.append('-')

# %%
print(len(R_title))
print(len(R_description))
print(len(contribution))
print(len(language))
# Out:
# 25
# 22
# 50
# 98

# %%
df=pd.DataFrame({'Title':R_title[:22],'Description':R_description,'Contribution':contribution[:22],'Language':language[:22]})

# %%
df
# Out:
#                              Title Description Contribution          Language
# 0                        wifi-card           -        2,671        JavaScript
# 1                            folly           -          117              HTML
# 2                IoT-For-Beginners           -       18,626               CSS
# 3                           ghidra           -        4,142          Makefile
# 4                      CBL-Mariner           -        3,651        Dockerfile
# 5                       OpenSearch           -          290               C++
# 6                       awesome-go           -       27,647            Python
# 7                    awesome-fenix           -        3,618             CMake
# 8                         Sa-Token           -          698                 C
# 9                              wtf           -           89             Shell
# 10                          GFPGAN           -        2,783          Assembly
# ...

# %% [markdown]
# # Q6. Scrape the details of top 100 songs on billboard.com.
#
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name B) Artist name C) Last week rank D) Peak rank E) Weeks on board Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
url='https://www.billboard.com/'
driver.get(url)

# %%
songs=driver.find_element_by_xpath("//a[@class='header__submenu__list__link']")
driver.get(songs.get_attribute('href'))

# %%
song=[]
artist=[]
rank=[]
peak=[]
wks=[]
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']"):
    song.append(i.text)
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    artist.append(i.text)
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']"):
    rank.append(i.text)
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    peak.append(i.text)
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']"):
    wks.append(i.text)

# %%
print(len(song))
print(len(artist))
print(len(rank))
print(len(peak))
print(len(wks))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
df=pd.DataFrame({'Song Name':song,'Atrist':artist,'Last week rank':rank,'Peak':peak,'WKS on board Note':wks})

# %%
df
# Out:
#                          Song Name  \
# 0                           Butter
# 1                         Good 4 U
# 2                       Levitating
# 3                     Kiss Me More
# 4   Montero (Call Me By Your Name)
# ..                             ...
# 95               All I Know So Far
# 96                     What's Next
# 97                  Enough For You
# 98                      Juggernaut
# 99                         Tell Em
#
#                                                Atrist Last week rank Peak  \
# 0                                                 BTS              1    1
# 1                                      Olivia Rodrigo              2    1
# 2                           Dua Lipa Featuring DaBaby              4    2
# 3                              Doja Cat Featuring SZA              3    3
# 4                                           Lil Nas X              8    1
# ..                                                ...            ...  ...
# ...

# %% [markdown]
# # Q7. Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name B) Designation C) Company D) Skills they hire for E) Location

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
recruiters=driver.find_element_by_xpath("/html/body/div[1]/div[1]/div/ul[1]/li[2]/div/ul/li[1]/a")
driver.get(recruiters.get_attribute('href'))

# %%
data_science=driver.find_element_by_xpath("//input[@class='sugInp']")
data_science.send_keys('Data Scientist')

# %%
search=driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search.click()

# %%
urls=[]
url=driver.find_elements_by_xpath("//a[@class='ellipsis']")
for i in url:
    urls.append(i.get_attribute('href'))

# %%
Name=[]
Des=[]
Com=[]
Skill=[]
Location=[]
##Name
try:
    for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
        Name.append(i.text)
except NoSuchAttributeException as e:
    Name.append('--')
## Description
try:
    for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
        Des.append(i.text)
except NoSuchAttributeException as e:
    Des.append('--')
## Company NAme
try:
    for i in driver.find_elements_by_xpath("//p[@class='highlightable']/a[2]"):
        Com.append(i.text)
except NoSuchAttributeException as e:
    Com.append('--')
## Skillset
try:
    for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
        Skill.append(i.text)
except NoSuchAttributeException as e:
    Skill.append('--')

# %%
for l in urls:
    driver.get(l)
    try:
        for i in driver.find_elements_by_xpath("//div[@class='rFrame fl infoWrapper']//div[5]//a"):
            Location.append(i.text)
    except NoSuchAttributeException as e:
        Location.append('--')

# %%
print(len(Name))
print(len(Des))
print(len(Com))
print(len(Skill))
print(len(Location))
# Out:
# 50
# 50
# 50
# 50
# 50

# %%
df=pd.DataFrame({'Name':Name,'Designation':Des,'Company':Com,'Skill':Skill,'Location':Location})

# %%
df
# Out:
#                                             Name  \
# 0                                      Tanushree
# 1                                  sashi bhushan
# 2                                         Bitapi
# 3                                 Gajendra Singh
# 4                              Sadashiv Kulkarni
# 5                                    Invelopment
# 6                              Anjali Srivastava
# 7                                Anoop Somarajan
# 8                                     Helly Vyas
# 9                                   Ashish Verma
# 10                              Bhuwneshari Devi
# 11                                    HS Sandesh
# 12                                   Datafoundry
# 13                               A Valsa Florina
# 14                                 Kalaivani M V
# 15                                    Prashant K
# 16                                       Radhika
# 17                                         Rakhi
# ...

# %% [markdown]
# # Q8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
#
# You have to find the following details:
#
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
driver.get(url)

# %%
book=[]
author=[]
volume=[]
pub=[]
genre=[]
for j in range(1,101):
    for i in driver.find_elements_by_xpath("//tbody/tr[{}]/td[2]".format(j)):
        book.append(i.text)
    for i in driver.find_elements_by_xpath("//tbody/tr[{}]/td[3]".format(j)):
        author.append(i.text)
    for i in driver.find_elements_by_xpath("//tbody/tr[{}]/td[4]".format(j)):
        volume.append(i.text)
    for i in driver.find_elements_by_xpath("//tbody/tr[{}]/td[5]".format(j)):
        pub.append(i.text)
    for i in driver.find_elements_by_xpath("//tbody/tr[{}]/td[6]".format(j)):
        genre.append(i.text)

# %%
print(len(book))
print(len(author))
print(len(volume))
print(len(pub))
print(len(genre))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
df=pd.DataFrame({'Book Name':book,'Author Name':author,'Volume Sold':volume,'Publisher':pub,'Genre':genre})

# %%
df
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume Sold        Publisher                        Genre
# ...

# %% [markdown]
# # Q9. Scrape the details most watched tv series of all time from imdb.com.
#
#  Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
Name=[]
Year=[]
Genre=[]
Time=[]
Rating=[]
Votes=[]
try:
    for i in driver.find_elements_by_xpath("//div[@class='lister-item mode-detail']/div[2]/h3/a"):
        Name.append(i.text)
except NoSuchAttributeException as e:
    Name.append('--')
try:
    for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
        Year.append(i.text)  
except NoSuchAttributeException as e:
     Year.append('--')
try:
    for i in driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[5]"):
        Genre.append(i.text)  
except NoSuchAttributeException as e:
    Genre.append('--')
try:
    for i in driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[3]"):
        Time.append(i.text)  
except NoSuchAttributeException as e:
    Time.append('--')  
try:
    for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']/div/span[2]"):
        Rating.append(i.text)  
except NoSuchAttributeException as e:
    Rating.append('--')   
try:
    for i in driver.find_elements_by_xpath("//span[@name='nv']"):
        Votes.append(i.text)  
except NoSuchAttributeException as e:
    Votes.append('--')

# %%
print(len(Name))
print(len(Year))
print(len(Genre))
print(len(Time))
print(len(Rating))
print(len(Votes))
# Out:
# 50
# 100
# 100
# 100
# 100
# 100

# %%
df=pd.DataFrame({'Name':Name,'Year':Year,'Genre':Genre,'Time_Span':Time,'Rating':Rating,'Votes':Votes})

# %%
df
# Out:
#                               Name         Year                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Time_Span Rating      Votes
# 0     57 min    9.2  1,835,393
# ...

# %% [markdown]
# # Q10. Details of Datasets from UCI machine learning repositories.
#
#  Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
url='https://archive.ics.uci.edu/'
driver.get(url)

# %%
uci=driver.find_element_by_xpath("//span[2][@class='whitetext']/a")
uci.click()

# %%
data=[]
typ=[]
task=[]
attribute=[]
number=[]
n_attribute=[]
year=[]
for i in driver.find_elements_by_xpath("//p[@class='normal']/b/a"):
    data.append(i.text)
for k in range(2,590):
    for i in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[2]/p".format(k)):
        typ.append(i.text)
    for i in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[3]/p".format(k)):
        task.append(i.text)
    for i in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[4]/p".format(k)):
        attribute.append(i.text)
    for i in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[5]/p".format(k)):
        number.append(i.text)
    for i in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[6]/p".format(k)):
        n_attribute.append(i.text)
    for i in driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[7]/p".format(k)):
        year.append(i.text)

# %%
print(len(data))
print(len(typ))
print(len(task))
print(len(attribute))
print(len(number))
print(len(n_attribute))
print(len(year))
# Out:
# 588
# 588
# 588
# 588
# 588
# 588
# 588

# %%
df=pd.DataFrame({'Dataset Name':data,'Data Type':typ,'Task':task,'Attribute type':attribute,'No of instances':number,'Number of Attribute':n_attribute,'Year':year})

# %%
df
# Out:
#                          Dataset Name      Data Type                  Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute type No of instances Number of Attribute   Year
# ...

# %% [markdown]
# # Thank You
